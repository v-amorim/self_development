# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import lib

# %%
path = 'assets'
img = [f'{path}/logo.jpg', 'logo BGR']

images = [
    [f'{path}/logo.jpg', 'logo BGR'],
    [f'{path}/logo.jpg', 'logo RGB', cv2.COLOR_BGR2RGB],
    [f'{path}/logo.jpg', 'logo GRAYSCALE', cv2.COLOR_BGR2GRAY],
    [f'{path}/ball.png', 'ball BGR'],
    [f'{path}/ball.png', 'ball RGB', cv2.COLOR_BGR2RGB],
    [f'{path}/ball.png', 'ball GRAYSCALE', cv2.COLOR_BGR2GRAY]
]


lib.show_images(images)
lib.show_image(img)
