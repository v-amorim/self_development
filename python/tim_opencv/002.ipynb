# %% [markdown]
# Tutorial using this playlist
#
# https://www.youtube.com/playlist?list=PLzMcBGfZo4-lUA8uGjeXhBUUzPYc6vZRn

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from lib import show_rgb_image

# %%
import itertools
import random


img = cv2.imread('img.jpg')
img2 = img.copy()

for i, j in itertools.product(range(20), range(img.shape[1])):
    img2[i, j] = [random.randint(0, 255), random.randint(0, 255), random.randint(0, 255)]

show_rgb_image(img2, title='Image')

# %%
img.shape
tag = img[85:130, 85:170]
show_rgb_image(tag, title='Tag')

# %%
img[0:45, 0:85] = tag
show_rgb_image(img, title='Image with tag')
